# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
angle_dist_us = pd.read_csv("../../data/angle_distance_us.csv")
angle_dist_ir = pd.read_csv("../../data/angle_distance_ir.csv")

# %%
angle_dist_us.head()
# Out:
#    angle  distance
# 0    -60      2550
# 1    -57      2550
# 2    -55      2550
# 3    -52      2550
# 4    -48      2550

# %%
angle_dist_ir.head()
# Out:
#    angle  distance
# 0    -80        67
# 1    -78        81
# 2    -74        66
# 3    -70        59
# 4    -66        51

# %%
angle_dist_us.plot(x='angle', y='distance', kind='scatter', 
                   xlim=(-45, 45), ylim=(100, 200), marker='+', title='ultrasonic');

# %%
angle_dist_ir.plot(x='angle', y='distance', kind='scatter', 
                   xlim=(-90, 90), marker='+', title='infrared');

# %%
fig = plt.figure(figsize=(7,7))
ax = plt.subplot(111, projection='polar')
ax.plot(deg2rad(angle_dist_ir.angle), angle_dist_ir.distance);
#xlim=(-80, 80), marker='+', title='infrared');

# %%
ax = plt.subplot(111, projection='polar')
ax.set_rmax(100)
ax.scatter([0, 0.6], [20, 80])

# %%
def deg2rad(deg):
    return deg * np.pi / 180

# %%
deg2rad(30)
# Out:
# 0.5235987755982988
